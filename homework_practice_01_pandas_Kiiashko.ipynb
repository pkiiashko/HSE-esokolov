# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 25.09.2024
#
# Мягкий дедлайн: 23:59MSK 06.10.2024
#
# Жесткий дедлайн: 23:59MSK 10.10.2024

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
#!wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
import wget
wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=75455c07d95be1af9ab941a79108218af38e20e8b5a16362eb6d4222678c246b
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
# 'end_seminar.xlsx'

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
df = pd.read_excel('end_seminar.xlsx')

# %%
df.tail(3)
# Out:
#                   timestamp                                id  rating  \
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 359       NaN    NaN                 Безопасность компьютерных систем
# 360       NaN    NaN                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 358                        Statistical Learning Theory
# 359  Принятие решений в условиях риска и неопределё...
# 360                      Моделирование временных рядов
#
#                                 fall_3  \
# 358  Анализ неструктурированных данных
# 359  Анализ неструктурированных данных
# 360  Высокопроизводительные вычисления
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       223 non-null    float64
#  4   is_mi          18 non-null     float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  359 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       138 non-null    float64
#  14  blended        138 non-null    object
#  15  is_ml_student  57 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 18-го года набора, а сколько из групп 17-го года?

# %%
print('Количество уникальных пользователей из 18 группы:',df.loc[df['18_group'].notna()]['id'].nunique())
# Out:
# Количество уникальных пользователей из 18 группы: 213

# %%
print('Количество уникальных пользователей из 17 группы:',df.loc[df['17_group'].notna()]['id'].nunique())
# Out:
# Количество уникальных пользователей из 17 группы: 134

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %%
print('Да, есть уникальные студенты с равными перцентилями') if df.loc[(df['percentile'].duplicated() == True) & (df['id'].duplicated() == False)]['id'].count() > 0 else print('Нет, у всех студентов разные перцентили')
# Out:
# Да, есть уникальные студенты с равными перцентилями

# %% [markdown]
# Вероятно, задублировались нулевые перцентили у студентов разных групп (студенты с самым низким рейтингом в разных группах):

# %%
df.loc[df['percentile'] == 0]
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
#
#      18_group  is_mi                            fall_1  \
# 80      182.0    NaN  Безопасность компьютерных систем
# 231       NaN    NaN       Statistical Learning Theory
#
#                                 fall_2                       fall_3  \
# 80         Statistical Learning Theory         Матричные вычисления
# 231  Высокопроизводительные вычисления  Statistical Learning Theory
#
#                    spring_1                                     spring_2  \
# 80   Дискретная оптимизация  Промышленное программирование на языке Java
# 231   Символьные вычисления                             Численные методы
#
#                                        spring_3 is_first_time  percentile  \
# 80   Дополнительные главы прикладной статистики            Да         0.0
# ...

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
df.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %%
df.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %% [markdown]
# В нашем случае в таблице присутствуют только числовые и строковые колонки, тип bool отсутствует, поэтому разделим все колонки на численные и строковые:

# %%
df[df.select_dtypes(include=['number']).columns] = df[df.select_dtypes(include=['number']).columns].fillna(0)
df[df.select_dtypes(exclude=['number']).columns] = df[df.select_dtypes(exclude=['number']).columns].fillna('')

df.head()
# Out:
#                 timestamp                                id  rating  18_group  \
# 0 2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698     181.0
# 1 2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647     181.0
# 2 2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624     185.0
# 3 2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579     182.0
# 4 2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572     183.0
#
#    is_mi                             fall_1  \
# 0    0.0                           Язык SQL
# 1    0.0  Высокопроизводительные вычисления
# 2    0.0   Безопасность компьютерных систем
# 3    0.0        Statistical Learning Theory
# 4    0.0  Высокопроизводительные вычисления
#
#                               fall_2                         fall_3  \
# 0  Высокопроизводительные вычисления           Матричные вычисления
# 1   Безопасность компьютерных систем                       Язык SQL
# ...

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
df['is_first_time'].describe()
# Out:
# count     361
# unique      3
# top        Да
# freq      308
# Name: is_first_time, dtype: object

# %%
print('Доля ответов Да:',"{0:.2f}%".format((df[df['is_first_time'] == 'Да']['is_first_time'].count() / len(df))*100))
print('Доля ответов Нет:',"{0:.2f}%".format((df[df['is_first_time'] == 'Нет']['is_first_time'].count() / len(df))*100))
print('Количество ответов Нет:',df[df['is_first_time'] == 'Нет']['is_first_time'].count())
# Out:
# Доля ответов Да: 85.32%
# Доля ответов Нет: 14.13%
# Количество ответов Нет: 51

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
df = df.sort_values('timestamp').drop_duplicates('id',keep='last')

# %% [markdown]
# Удалили 14 дубликатов с более ранней датой:

# %%
df.shape
# Out:
# (347, 16)

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
df.groupby(by='blended').agg({'id': 'count', 'percentile': 'mean'}).sort_values('percentile', ascending = False)
# Out:
#                                         id  percentile
# blended
# Соревновательный анализ данных          32    0.537817
# DevOps                                  87    0.502499
#                                        213    0.493610
# Введение в дифференциальную геометрию   15    0.343961

# %% [markdown]
# Согласно полученным данным, самый популярный курс среди студентов с самыми высокими рейтингами - Соревновательный анализ данных, на него записались 32 студента

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
grouped = df.groupby(by=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).agg({'id': 'count'})
grouped = grouped[grouped['id'] > 1]
print('Итого количество студентов с абсолютно одинаковыми предпочтениями:', grouped['id'].sum())
grouped.head()
# Out:
# Итого количество студентов с абсолютно одинаковыми предпочтениями: 32
#                                                                                                                                                                                                                                                                            id
# fall_1                                fall_2                            fall_3                                          spring_1                                           spring_2                                    spring_3                                   blended
# Statistical Learning Theory           Анализ неструктурированных данных Сбор и обработка данных с помощью краудсорсинга Обучение с подкреплением                           Конфликты и кооперация                      Компьютерное зрение                        DevOps    2
# ...

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
df8 = df.loc[df['18_group'] != 0]
unique18 = pd.unique(df8[['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].values.ravel('K')).tolist()

# %%
df7 = df.loc[df['17_group'] != 0]
unique17 = pd.unique(df7[['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].values.ravel('K')).tolist()

# %%
unique_all = unique18 + unique17
unique_all = pd.DataFrame(unique_all,columns=['courses'])

# %%
unique_all.loc[unique_all['courses'].duplicated() == True]
# Out:
#                                               courses
# 18                   Безопасность компьютерных систем
# 20                  Высокопроизводительные вычисления
# 21                        Statistical Learning Theory
# 24                      Моделирование временных рядов
# 25    Сбор и обработка данных с помощью краудсорсинга
# 26  Принятие решений в условиях риска и неопределё...
# 34                                   Численные методы

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
unique_all.loc[~unique_all.index.isin(unique_all.loc[unique_all['courses'].duplicated() == True].index)]
# Out:
#                                               courses
# 0                                            Язык SQL
# 1                   Высокопроизводительные вычисления
# 2                    Безопасность компьютерных систем
# 3                         Statistical Learning Theory
# 4                                   Теория баз данных
# 5   Принятие решений в условиях риска и неопределё...
# 6     Сбор и обработка данных с помощью краудсорсинга
# 7                                Матричные вычисления
# 8                       Моделирование временных рядов
# 9                              Дискретная оптимизация
# 10                                  Компьютерные сети
# 11        Промышленное программирование на языке Java
# 12                                   Численные методы
# 13         Дополнительные главы прикладной статистики
# 14                            Анализ данных в бизнесе
# 15                                Машинное обучение 2
# ...

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
grouped_2 = df.groupby(by=pd.DatetimeIndex(df['timestamp']).date).agg({'percentile': 'mean'})

# %%
ax = plt.bar(x=grouped_2.index,height=grouped_2['percentile'])
plt.xticks(ticks = grouped_2.index,labels = grouped_2.index,rotation=45)
plt.title("Средние рейтинги по дням получения ответов")
plt.xlabel("Дата")
plt.ylabel("Средний рейтинг")
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
from matplotlib.backends.backend_pdf import PdfPages

pdf = PdfPages("Средние рейтинги по дням получения ответов_1.pdf")


ax = plt.bar(x=grouped_2.index,height=grouped_2['percentile'])
plt.xticks(ticks = grouped_2.index,labels = grouped_2.index,rotation=45)
plt.title("Средние рейтинги по дням получения ответов")
plt.xlabel("Дата")
plt.ylabel("Средний рейтинг")

pdf.savefig()

pdf.close()

# %% [markdown]
# Почему-то просто функция plt.savefig() не сработала, создавался пустой пдф, взяла пример решения здесь: https://habr.com/ru/articles/544132/

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %% [markdown]
# Добавим колонку number_courses с указанием количества выбранных курсов для студентов 17 и 18 годов:

# %%
def set_number(row):
    if (row['is_mi'] == 1) or (row['17_group'] == 171) or (row['17_group'] == 172) or (row['17_group'] == 173):
        return 2
    else:
        return 1

df = df.assign(number_courses=df.apply(set_number, axis=1))

df.head()
# Out:
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
#
#                                    fall_2  \
# 223  Глубинное обучение в обработке звука
# 224         Моделирование временных рядов
# 225     Анализ неструктурированных данных
# ...

# %% [markdown]
# Проверка:

# %%
col_name = 'number_courses'    # insert your new column name as str

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %% [markdown]
# Для начала заменим на ??? повторные записи студентов на одни и те же курсы, чтобы один человек не записывался два раза на один курс. Если студент не прошел на курс по результатам первой волны (по рейтингу), то очевидно не сможет поступить и на следующих волнах, т.к. места закончатся. Если же он поступил с первой волны, то ему нет смысла участвовать в конкурсе дальше.

# %%
df.loc[df['fall_1'] == df['fall_2'],'fall_2'] = '???'
df.loc[df['fall_2'] == df['fall_3'], 'fall_3'] = '???'
df.loc[df['fall_1'] == df['fall_3'], 'fall_3'] = '???'
df.loc[df['spring_1'] == df['spring_2'],'spring_2'] = '???'
df.loc[df['spring_2'] == df['spring_3'], 'spring_3'] = '???'
df.loc[df['spring_1'] == df['spring_3'], 'spring_3'] = '???'

# %% [markdown]
# Объединим все данные по первому приоритету в один столбец, так как конкурс будет единый для студентов, которые выбирают 1 и 2 курса по выбору:

# %%
df_fall_1 = df.loc[df['number_courses'] == 2][['id','percentile','fall_2','number_courses']]
df_fall_1 = df_fall_1.rename(columns={'fall_2':'fall_1'})
df_fall_2 = pd.concat([df[['id','percentile','fall_1','number_courses']],df_fall_1]).reset_index(drop=True)
df_fall_2.head()
# Out:
#                                  id  percentile  \
# 0  d555d2805e1d93d4f023e57dc4c8f403    0.963768
# 1  253bbe1a2021d0404712a1e4acd22939    0.673913
# 2  881b1a6fda195b354ae2edb396a69f5d    0.782609
# 3  5a9b8ac11ad05b39a58b0e04a263bf4c    0.442029
# 4  1bbbfae51794b83c769b634be8da7b8d    0.789855
#
#                                  fall_1  number_courses
# 0      Безопасность компьютерных систем               2
# 1      Безопасность компьютерных систем               1
# 2      Безопасность компьютерных систем               2
# 3  Глубинное обучение в обработке звука               2
# 4      Безопасность компьютерных систем               1

# %% [markdown]
# Сравним количество студентов, записавшихся на курс, с количеством мест на каждом курсе. Для тех курсов, где значение diff положительное, будет проводиться вторая волна поступления. Для тех, где значение отрицательное, мы проводим конкурс студентов по рейтингу.

# %%
df_fall_grouped = df_fall_2.groupby(by = ['fall_1'])['id'].count()
df_fall_grouped = pd.DataFrame(df_fall_grouped).reset_index()

def set_max(row):
    if (row['fall_1'] == 'Высокопроизводительные вычисления') or (row['fall_1'] == 'Statistical Learning Theory'):
        return 60
    elif (row['fall_1'] == 'Анализ неструктурированных данных'):
        return 347
    else:
        return 30

df_fall_grouped = df_fall_grouped.assign(max_student=df_fall_grouped.apply(set_max, axis=1))
df_fall_grouped['diff'] = df_fall_grouped['max_student'] - df_fall_grouped['id']
df_fall_grouped
# Out:
#                                                fall_1   id  max_student  diff
# 0                                                 ???    2           30    28
# 1                         Statistical Learning Theory   33           60    27
# 2                   Анализ неструктурированных данных   48          347   299
# 3               Байесовские методы машинного обучения   24           30     6
# 4                    Безопасность компьютерных систем  115           30   -85
# 5                   Высокопроизводительные вычисления   44           60    16
# 6                Глубинное обучение в обработке звука   23           30     7
# 7                                Матричные вычисления   15           30    15
# 8                       Моделирование временных рядов   31           30    -1
# 9   Принятие решений в условиях риска и неопределё...    8           30    22
# 10    Сбор и обработка данных с помощью краудсорсинга   50           30   -20
# ...

# %% [markdown]
# Зачисляем студентов на курсы - всех студентов на курсы, где проводится вторая волна поступления, и студентов с наименьшим перцентилем на курсах, где мы провели конкурс:

# %%
courses_competition = df_fall_grouped.loc[df_fall_grouped['diff'] < 0]['fall_1'].tolist()
courses_sec_wave = df_fall_grouped.loc[df_fall_grouped['diff'] > 0]['fall_1'].tolist()

indexes = []

df_fall_2 = df_fall_2.reset_index()

for course in courses_competition:
  indexes.extend(df_fall_2.loc[df_fall_2['fall_1'] == course].nsmallest(30, 'percentile').index)

def set_enroll(row):

    if row['index'] in indexes:
        return 'да'
    elif row['fall_1'] == '???':
        return 'нет'
    elif row['fall_1'] in courses_sec_wave:
        return 'да'
    else:
        return 'нет'

df_fall_2 = df_fall_2.assign(enrolled=df_fall_2.apply(set_enroll, axis=1))

df_fall_2.head()
# Out:
#    index                                id  percentile  \
# 0      0  d555d2805e1d93d4f023e57dc4c8f403    0.963768
# 1      1  253bbe1a2021d0404712a1e4acd22939    0.673913
# 2      2  881b1a6fda195b354ae2edb396a69f5d    0.782609
# 3      3  5a9b8ac11ad05b39a58b0e04a263bf4c    0.442029
# 4      4  1bbbfae51794b83c769b634be8da7b8d    0.789855
#
#                                  fall_1  number_courses enrolled
# 0      Безопасность компьютерных систем               2      нет
# 1      Безопасность компьютерных систем               1      нет
# 2      Безопасность компьютерных систем               2      нет
# 3  Глубинное обучение в обработке звука               2       да
# 4      Безопасность компьютерных систем               1      нет

# %% [markdown]
# Добавим данные по первым и последним студентам по рейтингу на каждом курсе:

# %%
courses_all = courses_competition + courses_sec_wave

id_largest = []
for course in courses_all:
  id_largest.extend(df_fall_2.loc[(df_fall_2['enrolled'] == 'да') & (df_fall_2['fall_1'] == course)].nsmallest(1, 'percentile')['id'].tolist())

# %%
id_smallest = []
for course in courses_all:
  id_smallest.extend(df_fall_2.loc[(df_fall_2['enrolled'] == 'да') & (df_fall_2['fall_1'] == course)].nlargest(1, 'percentile')['id'].tolist())

# %%
def largest(row):

    if row['id'] in id_largest:
        return True

df = df.assign(is_first_place=df.apply(largest, axis=1))

def smallest(row):

    if row['id'] in id_smallest:
        return True

df = df.assign(is_last_place=df.apply(smallest, axis=1))

df.head()
# Out:
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
#
#                                    fall_2  \
# 223  Глубинное обучение в обработке звука
# 224         Моделирование временных рядов
# 225     Анализ неструктурированных данных
# ...

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %% [markdown]
# Добавим колонку wave_2 для проведения второй волны поступления на осенние курсы, для студентов с двумя курсами по выбору мы берем колонку fall_3, для студентов с одним курсом - fall_2

# %%
def set_wave_2(row):

    if (row['enrolled'] == 'нет') & (row['number_courses'] == 2):
        return df.loc[df['id'] == row['id']]['fall_3'].item()
    elif (row['enrolled'] == 'нет') & (row['number_courses'] == 1):
        return df.loc[df['id'] == row['id']]['fall_2'].item()

df_fall_2 = df_fall_2.assign(wave_2=df_fall_2.apply(set_wave_2, axis=1))
display(df_fall_2.loc[df_fall_2['enrolled'] == 'нет'].head())
# Out:
#    index                                id  percentile  \
# 0      0  d555d2805e1d93d4f023e57dc4c8f403    0.963768
# 1      1  253bbe1a2021d0404712a1e4acd22939    0.673913
# 2      2  881b1a6fda195b354ae2edb396a69f5d    0.782609
# 4      4  1bbbfae51794b83c769b634be8da7b8d    0.789855
# 5      5  8c3aa7371731bef999519c3de2c47423    0.695652
#
#                              fall_1  number_courses enrolled  \
# 0  Безопасность компьютерных систем               2      нет
# 1  Безопасность компьютерных систем               1      нет
# 2  Безопасность компьютерных систем               2      нет
# 4  Безопасность компьютерных систем               1      нет
# 5  Безопасность компьютерных систем               1      нет
#
#                                   wave_2
# 0  Байесовские методы машинного обучения
# 1          Моделирование временных рядов
# 2   Глубинное обучение в обработке звука
# 4      Высокопроизводительные вычисления
# 5      Высокопроизводительные вычисления

# %% [markdown]
# Так как мы дублировали в нашей таблице id для студентов, которые выбирают 2 курса, мы могли по предыдущим действиям добавить fall_3 два раза для одного id, если студент не поступил ни на один курс по результатам первой волны. Уберем данные задублированные записи:

# %%
df_fall_2['duplicated'] = df_fall_2.duplicated(subset=['id','wave_2'])
df_fall_2.loc[(df_fall_2['enrolled'] == 'нет') & (df_fall_2['duplicated'] == True),'wave_2'] = '???'
df_fall_2 = df_fall_2.drop(columns = ['duplicated'])

# %% [markdown]
# Аналогично первой волне посмотрим, на каких курсах требуется третья волна, а на каких будет проводиться конкурс по перцентилям:

# %%
df_fall_wave_2_grouped = df_fall_2.groupby(by = ['wave_2'])['id'].count()
df_fall_wave_2_grouped = pd.DataFrame(df_fall_wave_2_grouped).reset_index()
df_fall_wave_2_grouped = df_fall_wave_2_grouped.rename(columns={'wave_2':'fall_1'})
df_fall_wave_2_grouped = df_fall_wave_2_grouped.assign(max_student=df_fall_wave_2_grouped.apply(set_max, axis=1))
df_fall_wave_2_grouped['diff'] = df_fall_wave_2_grouped['max_student'] - df_fall_wave_2_grouped['id'] - df_fall_grouped['id']
df_fall_wave_2_grouped
# Out:
#                                                fall_1  id  max_student  diff
# 0                                                 ???   5           30    23
# 1                         Statistical Learning Theory   8           60    19
# 2                   Анализ неструктурированных данных   5          347   294
# 3               Байесовские методы машинного обучения   1           30     5
# 4                    Безопасность компьютерных систем   4           30   -89
# 5                   Высокопроизводительные вычисления  25           60    -9
# 6                Глубинное обучение в обработке звука   7           30     0
# 7                                Матричные вычисления   9           30     6
# 8                       Моделирование временных рядов  10           30   -11
# 9   Принятие решений в условиях риска и неопределё...   1           30    21
# 10    Сбор и обработка данных с помощью краудсорсинга  15           30   -35
# ...

# %% [markdown]
# При этом на первой волне у нас уже полностью заполнились места на 4х курсах, учтем их при конкурсе во второй волне.

# %%
courses_competition_all = df_fall_wave_2_grouped.loc[df_fall_wave_2_grouped['diff'] < 0]['fall_1'].tolist()
courses_sec_wave = df_fall_wave_2_grouped.loc[df_fall_wave_2_grouped['diff'] >= 0]['fall_1'].tolist()

courses_competition_2 = []
for i in courses_competition_all:
    if i in courses_competition:
        continue
    else:
        courses_competition_2.append(i)

courses_competition_2
# Out:
# ['Высокопроизводительные вычисления', 'Язык SQL']

# %% [markdown]
# Также учтем, что на курсах, где проводится конкурс во второй волне, уже осталось меньше мест для студентов после проведения первой волны зачисления.

# %%
indexes = []

for course in courses_competition_2:
  indexes.extend(df_fall_2.loc[df_fall_2['wave_2'] == course].nsmallest(df_fall_grouped.loc[df_fall_grouped['fall_1'] == course]['diff'].item(), 'percentile').index)

def set_enroll(row):

    if row['index'] in indexes:
        return 'да'
    elif row['wave_2'] == '???':
        return 'нет'
    elif row['wave_2'] in courses_sec_wave:
        return 'да'
    elif row['enrolled'] == 'нет':
        return 'нет'

df_fall_2 = df_fall_2.assign(enrolled_2=df_fall_2.apply(set_enroll, axis=1))

display(df_fall_2.loc[df_fall_2['enrolled_2'] == 'нет']['id'].count())
# Out:
# 56

# %% [markdown]
# После второй волны осталось 55 студентов, не зачисленных на курсы по выбору. Следующую волну мы проводим только для тех студентов, которые выбирают 1 курс по выбору, т.к. только они заполняли колонку для третьего приоритета

# %%
def set_wave_3(row):

    if (row['enrolled_2'] == 'нет') & (row['number_courses'] == 1):
        return df.loc[df['id'] == row['id']]['fall_3'].item()

df_fall_2 = df_fall_2.assign(wave_3=df_fall_2.apply(set_wave_3, axis=1))
display(df_fall_2.loc[df_fall_2['enrolled_2'] == 'нет'].head())
# Out:
#     index                                id  percentile  \
# 1       1  253bbe1a2021d0404712a1e4acd22939    0.673913
# 4       4  1bbbfae51794b83c769b634be8da7b8d    0.789855
# 5       5  8c3aa7371731bef999519c3de2c47423    0.695652
# 40     40  f0f6f3881894172a0f04e79b554b49e6    0.300448
# 48     48  180cf0e0dc7a6f88e76e3076cb761d26    0.869565
#
#                               fall_1  number_courses enrolled  \
# 1   Безопасность компьютерных систем               1      нет
# 4   Безопасность компьютерных систем               1      нет
# 5   Безопасность компьютерных систем               1      нет
# 40  Безопасность компьютерных систем               1      нет
# 48  Безопасность компьютерных систем               1      нет
#
#                                              wave_2 enrolled_2  \
# 1                     Моделирование временных рядов        нет
# 4                 Высокопроизводительные вычисления        нет
# ...

# %%
df_fall_wave_3_grouped = df_fall_2.groupby(by = ['wave_3'])['id'].count()
df_fall_wave_3_grouped = pd.DataFrame(df_fall_wave_3_grouped).reset_index()
df_fall_wave_3_grouped = df_fall_wave_3_grouped.rename(columns={'wave_3':'fall_1'})
df_fall_wave_3_grouped = df_fall_wave_3_grouped.assign(max_student=df_fall_wave_3_grouped.apply(set_max, axis=1))

# %%
df_fall_wave_3_grouped['diff'] = df_fall_wave_3_grouped['max_student'] - df_fall_wave_3_grouped['id']
df_fall_wave_4_grouped = df_fall_wave_3_grouped
df_fall_wave_4_grouped = df_fall_wave_4_grouped.merge(df_fall_grouped[['fall_1','id']],on='fall_1', how='left')
df_fall_wave_4_grouped = df_fall_wave_4_grouped.merge(df_fall_wave_2_grouped[['fall_1','id']],on='fall_1', how='left')
df_fall_wave_4_grouped['total_diff'] = df_fall_wave_4_grouped['diff'] - df_fall_wave_4_grouped['id'] - df_fall_wave_4_grouped['id_y']
df_fall_wave_4_grouped = df_fall_wave_4_grouped.rename(columns = {'id':'id_z','id_x':'id','diff':'diff_z','total_diff':'diff'})
df_fall_wave_4_grouped = df_fall_wave_4_grouped.drop(columns = ['diff_z','id_y','id_z'])
df_fall_wave_4_grouped
# Out:
#                                               fall_1  id  max_student  diff
# 0                        Statistical Learning Theory   2           60    17
# 1                  Анализ неструктурированных данных   3          347   291
# 2                  Высокопроизводительные вычисления   4           60   -13
# 3                               Матричные вычисления  10           30    -4
# 4                      Моделирование временных рядов   2           30   -13
# 5  Принятие решений в условиях риска и неопределё...   1           30    20
# 6    Сбор и обработка данных с помощью краудсорсинга   6           30   -41
# 7                                  Теория баз данных   6           30     6
# 8                                           Язык SQL   8           30   -21

# %% [markdown]
# Также проведем конкурс и зачислим всех студентов на курсы, где остались места.

# %%
courses_competition_all_2 = df_fall_wave_4_grouped.loc[df_fall_wave_4_grouped['diff'] < 0]['fall_1'].tolist()
courses_sec_wave = df_fall_wave_4_grouped.loc[df_fall_wave_4_grouped['diff'] >= 0]['fall_1'].tolist()

courses_competition_3 = []
for i in courses_competition_all_2:
    if i in courses_competition_all:
        continue
    else:
        courses_competition_3.append(i)

courses_competition_3
# Out:
# ['Матричные вычисления']

# %%
indexes_2 = []
indexes_2.extend(df_fall_2.loc[df_fall_2['wave_3'] == 'Матричные вычисления'].nsmallest(df_fall_wave_2_grouped.loc[df_fall_wave_2_grouped['fall_1'] == 'Матричные вычисления']['diff'].item(), 'percentile').index)

def set_enroll(row):

    if row['index'] in indexes_2:
        return 'да'
    elif row['wave_3'] in courses_sec_wave:
        return 'да'
    elif row['enrolled_2'] == 'нет':
        return 'нет'

df_fall_2 = df_fall_2.assign(enrolled_3=df_fall_2.apply(set_enroll, axis=1))

display(df_fall_2.loc[df_fall_2['enrolled_3'] == 'нет']['id'].count())
# Out:
# 38

# %% [markdown]
# Теперь объединим информацию о всех трех волнах в один столбец.

# %%
df_fall_3 = df_fall_2
def enroll_all(row):

    if row['enrolled'] == 'да':
        return row['fall_1']
    elif row['enrolled_2'] == 'да':
        return row['wave_2']
    elif row['enrolled_3'] == 'да':
        return row['wave_3']

df_fall_3 = df_fall_3.assign(enroll_total=df_fall_3.apply(enroll_all, axis=1))
df_fall_3.sample(5)
# Out:
#      index                                id  percentile  \
# 293    293  1c91e6c5375cf4a1cba48bdca79f7a78    0.130045
# 21      21  1528f0eaa027580820ccf0d92a53ad68    0.744395
# 208    208  25a3ce0eea214df2aa6d25d395d594f0    0.439462
# 163    163  6338b6eeb16faedc58d30d2f45c89a4c    0.579710
# 60      60  93c0280966ae263fe26c5d78f719f2ae    0.130435
#
#                                               fall_1  number_courses enrolled  \
# 293  Сбор и обработка данных с помощью краудсорсинга               1       да
# 21                       Statistical Learning Theory               1       да
# 208                    Моделирование временных рядов               1       да
# 163  Сбор и обработка данных с помощью краудсорсинга               2       да
# 60                 Анализ неструктурированных данных               2       да
#
#     wave_2 enrolled_2 wave_3 enrolled_3  \
# 293   None       None   None       None
# 21    None       None   None       None
# ...

# %%
df_fall_3 = df_fall_3.drop(columns = ['percentile','index','fall_1','enrolled',	'wave_2',	'enrolled_2',	'wave_3',	'enrolled_3','number_courses'])

# %% [markdown]
# Также разнесем информацию о студентах, которые выбирают по 2 курса, на 2 разных столбца. Теперь информация по id будет без дупликатов.

# %%
df_fall_3['duplicated'] = df_fall_3.duplicated(subset=['id'])
df_fall_3 = df_fall_3.fillna('???')
def fall_sec(row):

    if (row['duplicated'] == False) and (df_fall_3.loc[(df_fall_3['id'] == row['id'])]['id'].count() == 2):
        return df_fall_3.loc[(df_fall_3['id'] == row['id']) & (df_fall_3['duplicated'] == True)]['enroll_total'].item()
    else:
      return '-'
df_fall_3 = df_fall_3.assign(fall_2=df_fall_3.apply(fall_sec, axis=1))

df_fall_3.head()
# Out:
#                                  id                           enroll_total  \
# 0  d555d2805e1d93d4f023e57dc4c8f403  Байесовские методы машинного обучения
# 1  253bbe1a2021d0404712a1e4acd22939            Statistical Learning Theory
# 2  881b1a6fda195b354ae2edb396a69f5d   Глубинное обучение в обработке звука
# 3  5a9b8ac11ad05b39a58b0e04a263bf4c   Глубинное обучение в обработке звука
# 4  1bbbfae51794b83c769b634be8da7b8d      Анализ неструктурированных данных
#
#    duplicated                                fall_2
# 0       False  Глубинное обучение в обработке звука
# 1       False                                     -
# 2       False     Анализ неструктурированных данных
# 3       False           Statistical Learning Theory
# 4       False                                     -

# %%
df_fall_3 = df_fall_3.drop(df_fall_3[df_fall_3['duplicated'] == True].index)

# %%
df_fall_3 = df_fall_3.drop(columns = ['duplicated'])

# %%
df_fall_3 = df_fall_3.rename(columns={'enroll_total':'course1','fall_2':'course2','id':'ID'})
df_fall_3.head()
# Out:
#                                  ID                                course1  \
# 0  d555d2805e1d93d4f023e57dc4c8f403  Байесовские методы машинного обучения
# 1  253bbe1a2021d0404712a1e4acd22939            Statistical Learning Theory
# 2  881b1a6fda195b354ae2edb396a69f5d   Глубинное обучение в обработке звука
# 3  5a9b8ac11ad05b39a58b0e04a263bf4c   Глубинное обучение в обработке звука
# 4  1bbbfae51794b83c769b634be8da7b8d      Анализ неструктурированных данных
#
#                                 course2
# 0  Глубинное обучение в обработке звука
# 1                                     -
# 2     Анализ неструктурированных данных
# 3           Statistical Learning Theory
# 4                                     -

# %% [markdown]
# На всякий случай проверим количество строк в таблице:

# %%
df_fall_3.shape
# Out:
# (347, 3)

# %%
df_fall_3.to_csv('res_fall.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %% [markdown]
# Создадим столбец с указанием количества весенних курсов по выбору, которые должен выбрать студент.

# %%
def set_number(row):
    if (row['17_group'] == 171) or (row['17_group'] == 172) or (row['17_group'] == 173):
        return 2
    else:
        return 1

df = df.assign(number_courses_2=df.apply(set_number, axis=1))
df.head()
# Out:
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
#
#                                    fall_2  \
# 223  Глубинное обучение в обработке звука
# 224         Моделирование временных рядов
# 225     Анализ неструктурированных данных
# ...

# %% [markdown]
# Аналогично осенним курсам для начала объединим весь конкурс для первой волны весеннего набора в один столбец.

# %%
df_spring_1 = df.loc[(df['number_courses_2'] == 2)][['id','percentile','spring_2','number_courses_2','is_ml_student']]
df_spring_1 = df_spring_1.rename(columns={'spring_2':'spring_1'})

df_spring_3 = df[['id','spring_1','percentile','number_courses_2','is_ml_student']]
df_spring_3 = df_spring_3.rename(columns={'spring_1':'spring_x'})

def set_ml(row):
    if (row['is_ml_student'] > 0) and (row['spring_x'] == 'Машинное обучение 2'):
        return df.loc[df['id'] == row['id']]['spring_2'].item()
    else: return df.loc[df['id'] == row['id']]['spring_1'].item()

df_spring_3 = df_spring_3.assign(spring_1=df_spring_3.apply(set_ml, axis=1))
df_spring_3 = df_spring_3.drop(columns=['spring_x'])

df_spring_2 = pd.concat([df_spring_3,df_spring_1]).reset_index(drop=True)
df_spring_2.sample(5)
# Out:
#                                    id  percentile  number_courses_2  \
# 412  6a93fcbc79d0df6ddeba3b46739fc3d8    0.079710                 2
# 292  085da16dd3062b4790c3dabdc08a51cf    0.876812                 1
# 320  8fe79f84f36e3a5d2d6745621321302c    0.942029                 1
# 218  876b1fbacdfe36cb2e3927aea554b1ff    0.363229                 1
# 3    5a9b8ac11ad05b39a58b0e04a263bf4c    0.442029                 2
#
#      is_ml_student                                           spring_1
# 412            0.0            Генеративные модели в машинном обучении
# 292            0.0  Проектирование и разработка высоконагруженных ...
# 320            0.0                             Конфликты и кооперация
# 218            0.0                            Анализ данных в бизнесе
# 3              0.0                             Конфликты и кооперация

# %% [markdown]
# Проверим, что в нашей таблице добавились строчки для студентов с двумя курсами по выбору:

# %%
df_spring_2.shape
# Out:
# (420, 5)

# %%
df_spring_grouped = df_spring_2.groupby(by = ['spring_1'])['id'].count()
df_spring_grouped = pd.DataFrame(df_spring_grouped).reset_index()

def set_max(row):
    if (row['spring_1'] == 'Обучение с подкреплением') or (row['spring_1'] == 'Анализ данных в бизнесе'):
        return 60
    else:
        return 30

df_spring_grouped = df_spring_grouped.assign(max_student=df_spring_grouped.apply(set_max, axis=1))
df_spring_grouped['diff'] = df_spring_grouped['max_student'] - df_spring_grouped['id']
df_spring_grouped
# Out:
#                                              spring_1  id  max_student  diff
# 0                                                 ???   2           30    28
# 1                             Анализ данных в бизнесе  19           60    41
# 2             Генеративные модели в машинном обучении  16           30    14
# 3                              Дискретная оптимизация  31           30    -1
# 4          Дополнительные главы прикладной статистики  11           30    19
# 5                                 Компьютерное зрение  29           30     1
# 6                                   Компьютерные сети  43           30   -13
# 7                              Конфликты и кооперация  19           30    11
# 8                                 Машинное обучение 2  31           30    -1
# 9                Методы сжатия и передачи медиаданных  22           30     8
# 10                           Обучение с подкреплением  61           60    -1
# ...

# %% [markdown]
# Проведем конкурс для тех курсов, где уже заполнились все места, а для остальных курсов будет следующая волна поступления.

# %%
courses_competition = df_spring_grouped.loc[df_spring_grouped['diff'] < 0]['spring_1'].tolist()
courses_sec_wave = df_spring_grouped.loc[df_spring_grouped['diff'] >= 0]['spring_1'].tolist()

indexes = []

df_spring_2 = df_spring_2.reset_index()

for course in courses_competition:
  indexes.extend(df_spring_2.loc[df_spring_2['spring_1'] == course].nsmallest(df_spring_grouped.loc[df_spring_grouped['spring_1'] == course]['max_student'].item(), 'percentile').index)

def set_enroll(row):

    if row['index'] in indexes:
        return 'да'
    elif row['spring_1'] == '???':
        return 'нет'
    elif row['spring_1'] in courses_sec_wave:
        return 'да'
    else:
        return 'нет'

df_spring_2 = df_spring_2.assign(enrolled=df_spring_2.apply(set_enroll, axis=1))

df_spring_2.head()
# Out:
#    index                                id  percentile  number_courses_2  \
# 0      0  d555d2805e1d93d4f023e57dc4c8f403    0.963768                 2
# 1      1  253bbe1a2021d0404712a1e4acd22939    0.673913                 1
# 2      2  881b1a6fda195b354ae2edb396a69f5d    0.782609                 2
# 3      3  5a9b8ac11ad05b39a58b0e04a263bf4c    0.442029                 2
# 4      4  1bbbfae51794b83c769b634be8da7b8d    0.789855                 1
#
#    is_ml_student                                           spring_1 enrolled
# 0            0.0                                Компьютерное зрение       да
# 1            0.0  Проектирование и разработка высоконагруженных ...      нет
# 2            0.0                                Компьютерное зрение       да
# 3            0.0                             Конфликты и кооперация       да
# 4            0.0  Проектирование и разработка высоконагруженных ...      нет

# %%
df_spring_2 = df_spring_2.rename(columns={'number_courses_2':'number_courses'})

# %% [markdown]
# Добавим столбец с информацией для второй волны, при этог учтем, что для студентов с двумя курсами, мы берем третий приоритет,  а также для студентов 4го курса специализации МО сдвинем приоритеты, если они выбрали курс МО.

# %%
def set_wave_2(row):

    if (row['enrolled'] == 'нет') & (row['number_courses'] == 2):
        return df.loc[df['id'] == row['id']]['spring_3'].item()
    elif (row['enrolled'] == 'нет') & (row['is_ml_student'] > 0) & (df.loc[df['id'] == row['id']]['spring_2'].item() == 'Машинное обучение 2'):
        return df.loc[df['id'] == row['id']]['spring_3'].item()
    elif (row['enrolled'] == 'нет') & (row['number_courses'] == 1):
        return df.loc[df['id'] == row['id']]['spring_2'].item()


df_spring_2 = df_spring_2.assign(wave_2=df_spring_2.apply(set_wave_2, axis=1))
display(df_spring_2.loc[df_spring_2['enrolled'] == 'нет'].head())
# Out:
#     index                                id  percentile  number_courses  \
# 1       1  253bbe1a2021d0404712a1e4acd22939    0.673913               1
# 4       4  1bbbfae51794b83c769b634be8da7b8d    0.789855               1
# 5       5  8c3aa7371731bef999519c3de2c47423    0.695652               1
# 9       9  2ca6917be428f8b84f6f15cdcbea2143    0.818841               2
# 22     22  496ea4f0d4abe264b1bb1b80eb3830c5    0.780269               1
#
#     is_ml_student                                           spring_1 enrolled  \
# 1             0.0  Проектирование и разработка высоконагруженных ...      нет
# 4             0.0  Проектирование и разработка высоконагруженных ...      нет
# 5             0.0  Проектирование и разработка высоконагруженных ...      нет
# 9             0.0  Проектирование и разработка высоконагруженных ...      нет
# 22            0.0                                  Компьютерные сети      нет
#
#                                      wave_2
# ...

# %% [markdown]
# Также заполним пропусками задублированные записи для студентов, выбирающих по 2 весенних курса.

# %%
df_spring_2['duplicated'] = df_spring_2.duplicated(subset=['id','wave_2'])
df_spring_2.loc[(df_spring_2['enrolled'] == 'нет') & (df_spring_2['duplicated'] == True),'wave_2'] = '???'
df_spring_2 = df_spring_2.drop(columns = ['duplicated'])

# %% [markdown]
# Объединим всю полученную информацию по зачислению на курсы в одну таблицу:

# %%
df_spring_wave_2_grouped = df_spring_2.groupby(by = ['wave_2'])['id'].count()
df_spring_wave_2_grouped = pd.DataFrame(df_spring_wave_2_grouped).reset_index()
df_spring_wave_2_grouped = df_spring_wave_2_grouped.rename(columns={'wave_2':'spring_1'})
df_spring_wave_2_grouped = df_spring_wave_2_grouped.assign(max_student=df_spring_wave_2_grouped.apply(set_max, axis=1))

# %%
df_spring_wave_2_grouped
df_spring_wave_2_grouped['diff'] = df_spring_wave_2_grouped['max_student'] - df_spring_wave_2_grouped['id']
df_spring_wave_2_grouped = df_spring_wave_2_grouped.merge(df_spring_grouped[['spring_1','id']],on='spring_1', how='left')

df_spring_wave_2_grouped['total_diff'] = df_spring_wave_2_grouped['diff'] - df_spring_wave_2_grouped['id_y']
df_spring_wave_2_grouped = df_spring_wave_2_grouped.rename(columns = {'id_x':'id','diff':'diff_z','total_diff':'diff'})
df_spring_wave_2_grouped = df_spring_wave_2_grouped.drop(columns = ['diff_z','id_y'])
df_spring_wave_2_grouped
# Out:
#                                        spring_1  id  max_student  diff
# 0                                           ???   1           30    27
# 1                       Анализ данных в бизнесе   8           60    33
# 2       Генеративные модели в машинном обучении   2           30    12
# 3                        Дискретная оптимизация   3           30    -4
# 4    Дополнительные главы прикладной статистики   3           30    16
# 5                           Компьютерное зрение   5           30    -4
# 6                             Компьютерные сети  13           30   -26
# 7                        Конфликты и кооперация   1           30    10
# 8                           Машинное обучение 2   6           30    -7
# 9          Методы сжатия и передачи медиаданных   6           30     2
# 10                     Обучение с подкреплением   1           60    -2
# 11  Промышленное программирование на языке Java  10           30   -43
# ...

# %%
courses_competition_all = df_spring_wave_2_grouped.loc[df_spring_wave_2_grouped['diff'] < 0]['spring_1'].tolist()
courses_sec_wave = df_spring_wave_2_grouped.loc[df_spring_wave_2_grouped['diff'] >= 0]['spring_1'].tolist()

courses_competition_2 = []
for i in courses_competition_all:
    if i in courses_competition:
        continue
    else:
        courses_competition_2.append(i)

courses_competition_2
# Out:
# ['Компьютерное зрение']

# %% [markdown]
# В этой волне конкурс проводится только по курсу Компьютерное зрение.

# %%
indexes = []

for course in courses_competition_2:
  indexes.extend(df_spring_2.loc[df_spring_2['wave_2'] == course].nsmallest(df_spring_grouped.loc[df_spring_grouped['spring_1'] == course]['diff'].item(), 'percentile').index)

def set_enroll(row):

    if row['index'] in indexes:
        return 'да'
    elif row['wave_2'] in courses_sec_wave:
        return 'да'
    elif row['enrolled'] == 'нет':
        return 'нет'

df_spring_2 = df_spring_2.assign(enrolled_2=df_spring_2.apply(set_enroll, axis=1))

display(df_spring_2.loc[df_spring_2['enrolled_2'] == 'нет']['id'].count())
# Out:
# 37

# %% [markdown]
# Еще 37 студентов не были зачислены на курс по итогам двух волн. Так как в таблице всего 3 столбца для приоритетов, то в третью волну нет необходимости сдвигать приоритеты для студентов специализации МО, выбравших курс МО-2.

# %%
def set_wave_3(row):

    if (row['enrolled_2'] == 'нет') & (row['is_ml_student'] > 0) & (df.loc[df['id'] == row['id']]['spring_3'].item() == 'Машинное обучение 2'):
        return '???'
    elif (row['enrolled_2'] == 'нет') & (row['number_courses'] == 1):
        return df.loc[df['id'] == row['id']]['spring_3'].item()
df_spring_2 = df_spring_2.assign(wave_3=df_spring_2.apply(set_wave_3, axis=1))
display(df_spring_2.loc[df_spring_2['enrolled_2'] == 'нет'].head())
# Out:
#     index                                id  percentile  number_courses  \
# 22     22  496ea4f0d4abe264b1bb1b80eb3830c5    0.780269               1
# 25     25  8047c18b3c531c6f47931e0744f3e028    0.802691               1
# 45     45  d82c2df25b8b36cd655077b4a885e1f7    0.596413               1
# 49     49  5daee1bd98559bb2c52373e416942225    0.681614               1
# 61     61  e3d4f9a7b947ebc03d345dd9e14b5d2c    0.959641               1
#
#     is_ml_student                                     spring_1 enrolled  \
# 22            0.0                            Компьютерные сети      нет
# 25            0.0  Промышленное программирование на языке Java      нет
# 45            0.0  Промышленное программирование на языке Java      нет
# 49            1.0  Промышленное программирование на языке Java      нет
# 61            0.0                       Дискретная оптимизация      нет
#
#                                          wave_2 enrolled_2  \
# ...

# %%
df_spring_wave_3_grouped = df_spring_2.groupby(by = ['wave_3'])['id'].count()
df_spring_wave_3_grouped = pd.DataFrame(df_spring_wave_3_grouped).reset_index()
df_spring_wave_3_grouped = df_spring_wave_3_grouped.rename(columns={'wave_3':'spring_1'})
df_spring_wave_3_grouped = df_spring_wave_3_grouped.assign(max_student=df_spring_wave_3_grouped.apply(set_max, axis=1))

# %%
df_spring_wave_3_grouped['diff'] = df_spring_wave_3_grouped['max_student'] - df_spring_wave_3_grouped['id']

df_spring_wave_3_grouped = df_spring_wave_3_grouped.merge(df_spring_grouped[['spring_1','id']],on='spring_1', how='left')
df_spring_wave_3_grouped = df_spring_wave_3_grouped.merge(df_spring_wave_2_grouped[['spring_1','id']],on='spring_1', how='left')
df_spring_wave_3_grouped['total_diff'] = df_spring_wave_3_grouped['diff'] - df_spring_wave_3_grouped['id_y'] - df_spring_wave_3_grouped['id']
df_spring_wave_3_grouped = df_spring_wave_3_grouped.rename(columns = {'id':'id_z','id_x':'id','diff':'diff_z','total_diff':'diff'})
df_spring_wave_3_grouped = df_spring_wave_3_grouped.drop(columns = ['diff_z','id_y','id_z'])
df_spring_wave_3_grouped
# Out:
#                                             spring_1  id  max_student  diff
# 0                            Анализ данных в бизнесе   5           60  28.0
# 1                             Дискретная оптимизация   8           30 -12.0
# 2         Дополнительные главы прикладной статистики   1           30  15.0
# 3                                  Компьютерные сети   7           30 -33.0
# 4                                Машинное обучение 2   2           30  -9.0
# 5  Проектирование и разработка высоконагруженных ...   1           30   NaN
# 6        Промышленное программирование на языке Java   1           30 -44.0
# 7                                 Системы баз данных   6           30  13.0
# 8                                   Численные методы   2           30  14.0

# %%
df_spring_wave_3_grouped['diff_2'] = df_spring_wave_3_grouped['diff'] + df_spring_wave_3_grouped['id']
courses_competition = df_spring_wave_3_grouped.loc[(df_spring_wave_3_grouped['diff_2'] > 0) & (df_spring_wave_3_grouped['diff'] < 0)]['spring_1'].tolist()
courses_competition
# Out:
# []

# %% [markdown]
# Для третьей волны у нас не будет курсов, на которые нужно проводить конкурс по рейтингу, поэтому просто зачисляем на курсы, где остались места, всех студентов, которые выбрали этот курс как третий приоритет.

# %%
courses_sec_wave = df_spring_wave_3_grouped.loc[df_spring_wave_3_grouped['diff'] >= 0]['spring_1'].tolist()
courses_sec_wave
# Out:
# ['Анализ данных в бизнесе',
#  'Дополнительные главы прикладной статистики',
#  'Системы баз данных',
#  'Численные методы']

# %%
def set_enroll(row):

    if row['wave_3'] in courses_sec_wave:
        return 'да'
    elif row['enrolled_2'] == 'нет':
        return 'нет'

df_spring_2 = df_spring_2.assign(enrolled_3=df_spring_2.apply(set_enroll, axis=1))

display(df_spring_2.loc[df_spring_2['enrolled_3'] == 'нет']['id'].count())
# Out:
# 23

# %% [markdown]
# Итого 23 студента не были распределены на весенние курсы по выбору по итогам трех волн. Теперь просто уберем из таблицы все лишние столбцы для выгрузки.

# %%
df_spring_3 = df_spring_2
def enroll_all(row):

    if row['enrolled'] == 'да':
        return row['spring_1']
    elif row['enrolled_2'] == 'да':
        return row['wave_2']
    elif row['enrolled_3'] == 'да':
        return row['wave_3']

df_spring_3 = df_spring_3.assign(enroll_total=df_spring_3.apply(enroll_all, axis=1))
df_spring_3.sample(5)
# Out:
#      index                                id  percentile  number_courses  \
# 407    407  67e4ec4fe5c0601815692fbd6d403fb7    0.014493               2
# 279    279  ba028043babda44219f3346809874ca3    0.427536               1
# 179    179  8c191b9ac692c190f54e66167b0adc3e    0.556054               1
# 40      40  f0f6f3881894172a0f04e79b554b49e6    0.300448               1
# 346    346  9d19b0d5f4fc8d7edc2258406f872c4e    0.197309               1
#
#      is_ml_student                                           spring_1  \
# 407            0.0  Проектирование и разработка высоконагруженных ...
# 279            0.0  Проектирование и разработка высоконагруженных ...
# 179            0.0                            Анализ данных в бизнесе
# 40             1.0                                   Численные методы
# 346            0.0                                  Компьютерные сети
#
#     enrolled wave_2 enrolled_2 wave_3 enrolled_3  \
# 407       да   None       None   None       None
# ...

# %%
df_spring_3 = df_spring_3.drop(columns = ['percentile','index','spring_1','enrolled',	'wave_2',	'enrolled_2',	'wave_3',	'enrolled_3','number_courses','is_ml_student'])

# %%
df_spring_3['duplicated'] = df_spring_3.duplicated(subset=['id'])
df_spring_3 = df_spring_3.fillna('???')
def fall_sec(row):

    if (row['duplicated'] == False) and (df_spring_3.loc[(df_spring_3['id'] == row['id'])]['id'].count() == 2):
        return df_spring_3.loc[(df_spring_3['id'] == row['id']) & (df_spring_3['duplicated'] == True)]['enroll_total'].item()
    else:
      return '-'
df_spring_3 = df_spring_3.assign(spring_2=df_spring_3.apply(fall_sec, axis=1))

df_spring_3.head()
# Out:
#                                  id                          enroll_total  \
# 0  d555d2805e1d93d4f023e57dc4c8f403                   Компьютерное зрение
# 1  253bbe1a2021d0404712a1e4acd22939                      Численные методы
# 2  881b1a6fda195b354ae2edb396a69f5d                   Компьютерное зрение
# 3  5a9b8ac11ad05b39a58b0e04a263bf4c                Конфликты и кооперация
# 4  1bbbfae51794b83c769b634be8da7b8d  Методы сжатия и передачи медиаданных
#
#    duplicated                                 spring_2
# 0       False                 Обучение с подкреплением
# 1       False                                        -
# 2       False  Генеративные модели в машинном обучении
# 3       False                 Обучение с подкреплением
# 4       False                                        -

# %%
df_spring_3 = df_spring_3.drop(df_spring_3[df_spring_3['duplicated'] == True].index)

# %%
df_spring_3 = df_spring_3.drop(columns = ['duplicated'])

# %%
df_spring_3 = df_spring_3.rename(columns={'enroll_total':'course1','spring_2':'course2','id':'ID'})
df_spring_3.head()
# Out:
#                                  ID                               course1  \
# 0  d555d2805e1d93d4f023e57dc4c8f403                   Компьютерное зрение
# 1  253bbe1a2021d0404712a1e4acd22939                      Численные методы
# 2  881b1a6fda195b354ae2edb396a69f5d                   Компьютерное зрение
# 3  5a9b8ac11ad05b39a58b0e04a263bf4c                Конфликты и кооперация
# 4  1bbbfae51794b83c769b634be8da7b8d  Методы сжатия и передачи медиаданных
#
#                                    course2
# 0                 Обучение с подкреплением
# 1                                        -
# 2  Генеративные модели в машинном обучении
# 3                 Обучение с подкреплением
# 4                                        -

# %% [markdown]
# Убедимся в том, что id в таблице остались уникальные по количеству:

# %%
df_spring_3.shape
# Out:
# (347, 3)

# %%
df_spring_3.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3EiwhvVaBJQRuSNOOUMUTrXUqtJ6JNfT__1igmKETAkCdCJEjgFSdxCIQ10150E8BPjw&usqp=CAU" style="width: 400px">
